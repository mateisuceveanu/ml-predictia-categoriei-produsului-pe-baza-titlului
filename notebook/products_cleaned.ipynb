# %% [markdown]
# <a href="https://colab.research.google.com/github/mateisuceveanu/ml-predictia-categoriei-produsului-pe-baza-titlului/blob/main/notebook/products_cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task - Sarcina 3 – Predicția categoriei produsului pe baza titlului
# ##Suceveanu Matei

# %% [markdown]
# #Acest pas are rolul de a standardiza elemente utile din CSV-ul folosit ulterior

# %% [markdown]
# ##1. Format column titles

# %%
import pandas as pd

df= pd.read_csv(r"C:\Task final LA\ml-predictia-categoriei-produsului-pe-baza-titlului\data\IMLP4_TASK_03-products.csv")

#Format column titles
df.columns = (
    df.columns
    .str.replace("_", " ")
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)
print(df.columns)

# %% [markdown]
# ##2. Edit columns, standardize format, drop nan

# %%
#print number of rows and columns
print("Number of rows and columns:", df.shape)

#print the nuber of null per column
print("Missing values pe column:")
print(df.isna().sum())

#print unique val of sentiment column
print("Unique values:")
print(df['category_label'].unique())

#uniform format usefull columns
df["category_label"] = df["category_label"].str.lower().str.strip()
df["product_title"] = df["product_title"].str.lower().str.strip()
print(df["category_label"].unique())

#Drop na val
df = df.dropna()
print(df["category_label"].unique())

# %% [markdown]
# ##3. Format atipic column content

# %%
#normalize lables
df["category_label"] = df["category_label"].replace({
    "cpu": "cpus",
    "fridge": "fridges",
    "mobile phone": "mobile phones"
})

# %% [markdown]
# ##4. Save cleaned CSV

# %%
#save cleaned datasheet
df.to_csv(r"C:\Task final LA\ml-predictia-categoriei-produsului-pe-baza-titlului\data\IMLP4_TASK_03-products_cleaned.csv", index=False)

# %% [markdown]
# ###Conclusion - CSV file formated for future use
